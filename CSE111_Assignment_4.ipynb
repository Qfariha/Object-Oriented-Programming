# %%
#task-1
class Customer:
  def __init__(self,name):
    self.name=name
  def greet(self,n=None):
    self.name1=n
    if self.name1==None:
      print("Hello!")
    else:
      print(f"Hello {self.name1}!")
  def purchase(self,*items):
    self.list1=list(items)
    print(self.name,", you have puchased",len(self.list1),"item(s):")
    for item in self.list1:
      print(item)


customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam , you have puchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello David!
# David , you have puchased 1 item(s):
# orange juice

# %%
#task-2
class Panda:
  def __init__(self,n,g,a):
    self.name=n
    self.gender=g
    self.age=a
  def sleep(self,h=None):
    self.s_hour=h
    if self.s_hour==None:
      return (f"{self.name}'s duration is unknown thus should have only bamboo leaves")
    elif 3<=self.s_hour<=5:
      return (f"{self.name} sleeps {self.s_hour} hours daily and should have Mixed Veggies")
    elif 6<=self.s_hour<=8:
      print (f"{self.name} sleeps {self.s_hour} hours daily and should have Eggplant & Tofu")
    elif 9<=self.s_hour<=11:
      return (f"{self.name} sleeps {self.s_hour} hours daily and should have Broccoli chicken")


panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#task-3
class Cat:
  def __init__(self,c="White",t="sitting"):
    self.color=c
    self.task=t
  def printCat(self):
    print(f'{self.color} cat is {self.task}')
  def changeColor(self,c1):
    self.color=c1

    
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#task-4
class Student:
  def __init__(self,n=None):
    self.name=n

    self.list1=[]
    
    self.avg=0
    
  def quizcalc(self,*nums):
    #self.list1+=nums
    self.list1+=list(nums) #same
    print(self.list1,"self.list1")
    total=0
    for num in self.list1:
      total+=num
    self.avg=total/3
  def printdetail(self):
    if self.name==None:
      print("Hello default student")
      
    else:
      print("Hello",self.name)
    print("Your average quiz score is",self.avg)
      


s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# [10] self.list1
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# [10, 8] self.list1
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# [10, 9, 10] self.list1
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#task-5
class Student:
  def __init__(self,n=None,id=None,dept=None):
    self.name=n
    self.id=id
    self.dept=dept

  def dailyEffort(self,h):
    self.effort=h

  def printDetails(self):
    if self.dept==None:
      self.dept="CSE"
    if self.effort<=2:
      print (f'Name: {self.name}\nID: {self.id}\nDepartment: {self.dept}\nDaily Effort: {self.effort} hour(s)\nSuggestion: Should give more effort!')
    elif self.effort<=4:
      print (f'Name: {self.name}\nID: {self.id}\nDepartment: {self.dept}\nDaily Effort: {self.effort} hour(s)\nSuggestion: Keep up the good work!')
    else:
      print (f'Name: {self.name}\nID: {self.id}\nDepartment: {self.dept}\nDaily Effort: {self.effort} hour(s)\nSuggestion: Excellent!Now motivate others.')

harry = Student('Harry Potter', 123)
harry.dailyEffort(3)
harry.printDetails()
print('========================')
john = Student("John Wick", 456, "BBA")
john.dailyEffort(2)
john.printDetails()
print('========================')
naruto = Student("Naruto Uzumaki", 777, "Ninja")
naruto.dailyEffort(6)
naruto.printDetails()
# Out:
# Name: Harry Potter
# ID: 123
# Department: CSE
# Daily Effort: 3 hour(s)
# Suggestion: Keep up the good work!
# ...
# Name: John Wick
# ID: 456
# Department: BBA
# Daily Effort: 2 hour(s)
# Suggestion: Should give more effort!
# ...
# Name: Naruto Uzumaki
# ID: 777
# Department: Ninja
# Daily Effort: 6 hour(s)
# Suggestion: Excellent!Now motivate others.

# %%
#task-6
class Patient:
  def __init__(self,n,a):
    self.name=n
    self.age=a
    self.list1=[]
  def add_Symptom(self,*symps):
    self.symptoms=list(symps)
    self.list1+=self.symptoms
  def printPatientDetail(self):
    self.symps=", ".join(self.list1)
    print (f'Name: {self.name} \nAge: {self.age} \nSymptoms: {self.symps}')

p1 = Patient("Thomas", 23)
p1.add_Symptom("Headache")
p2 = Patient("Carol",20 )
p2.add_Symptom("Vomiting", "Coughing")
p3 = Patient("Mike", 25)
p3.add_Symptom("Fever", "Headache", "Coughing")
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptoms: Headache
# ...
# Name: Carol
# Age: 20
# Symptoms: Vomiting, Coughing
# ...
# Name: Mike
# Age: 25
# Symptoms: Fever, Headache, Coughing

# %%
#task-7
class Match:
  def __init__(self,n):
    list1=n.split("-")
    self.t1=list1[0]
    self.t2=list1[1]
    print("5..4..3..2..1.. Play !!!")
    self.run=0
    self.over=0
    self.wicket=0
  def add_run(self,r):
    self.run+=r
  def add_over(self,o):
    if o<5:
      self.over+=o
    if o>=5:
      print("Warning! Cannot add",o,"over/s (5 over match)")
  def add_wicket(self,w):
    self.wicket+=w
  def print_scoreboard(self):
    return (f'Batting Team: {self.t1} \nBowling Team: {self.t2} \nTotal Runs: {self.run} Wickets: {self.wicket} Overs: {self.over}')
match1 = Match("Rangpur Riders-Cumilla Victorians")
print("=========================")
match1.add_run(4)
match1.add_run(6)
match1.add_over(1)
print(match1.print_scoreboard())
print("=========================")
match1.add_over(5)
print("=========================")
match1.add_wicket(1)
print(match1.print_scoreboard())
# Out:
# 5..4..3..2..1.. Play !!!
# ...
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 0 Overs: 1
# ...
# Warning! Cannot add 5 over/s (5 over match)
# ...
# Batting Team: Rangpur Riders
# Bowling Team: Cumilla Victorians
# Total Runs: 10 Wickets: 1 Overs: 1

# %%
#task-8
class ParcelKoro:
  def __init__(self,n=None,w=None):
    self.name=n
    if self.name==None:
      self.name="No Name Set"
    self.product_weight=w 
    if self.product_weight==None:
      self.product_weight=0
      

  def calculateFee(self,l=None):
    self.l_charge=0
    self.total=0
    self.delivery=l
    if self.delivery==None:
      self.l_charge=50
    else:
      self.l_charge=100
    if self.product_weight==0:
      self.total=0
    else:
      self.total=(self.product_weight*20)+self.l_charge
  def printDetails(self):
    print(f'Customer Name:{self.name} \nProduct Weight:{self.product_weight} \nTotal fee:{self.total}')
print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3=ParcelKoro("Dora The Explorer",10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name:No Name Set
# Product Weight:0
# Total fee:0
# **********************
# Customer Name:Bob The Builder
# Product Weight:0
# Total fee:0
# ----------------------------
# Customer Name:Bob The Builder
# Product Weight:15
# Total fee:350
# **********************
# Customer Name:Dora The Explorer
# Product Weight:10
# Total fee:300

# %%
#task-9
class Batsman:
  def __init__(self,*args):
    list1=list(args)
    if len(list1)==3:
      self.name=list1[0]
      self.runs=list1[1]
      self.balls_faced=list1[2]
    elif len(list1)==2:
      self.name="New Batsman"
      self.runs=list1[0]
      self.balls_faced=list1[1]
    self.ans=0
  def battingStrikeRate(self):
    self.ans=(self.runs/self.balls_faced)*100
    return self.ans
  def setName(self,n1):
    self.name=n1 
  def printCareerStatistics(self):
    print(f'Name: {self.name} \nRuns Scored: {self.runs} , Balls Faced: {self.balls_faced}')
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101 , Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678 , Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101 , Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#task-10
class EPL_Team:
  def __init__(self,n=None,s=None,t=0):
    self.name=n
    self.song=s
    if self.song==None:
      self.song="No Slogan"
    self.title=t
  def increaseTitle(self):
    self.title+=1
  def changeSong(self,s1):
    self.song=s1
  def showClubInfo(self):
    return (f'Name: {self.name} \nSong: {self.song} \nTotal No of title:{self.title} ')
manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title:0
# ##################
# Name: Manchester United
# Song: Glory Glory Man United
# Total No of title:1
# ...
# Name: Chelsea
# Song: No Slogan
# Total No of title:0
# Name: Chelsea
# Song: Keep the blue flag flying high
# Total No of title:0

# %%
#task-11
class Author:
  def __init__(self,*info):
    self.list1=[]
    self.list2=[]
    self.info=list(info)
    if len(self.info)==1:
      self.name=self.info[0]
    elif len(self.info)==0:
      self.name="Default"
    elif len(self.info)>1:
      
      for index in range(len(self.info)):
        if index!=0:
          self.list2.append(self.info[index])
        else:
          self.name=self.info[index]
      #self.name=self.list1[0]
    #print(self.list1,"self.list1")

  def addBooks(self,*books):
    self.b_list=list(books)
    self.list2+=self.b_list

  def changeName(self,n):
    self.name=n

  def printDetails(self):
    print("Author Name:",self.name)
    print("---------")
    print('Lists of books:')
    for elem in self.list2:
      print(elem)
      
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal', 'Megher Opor Bari')
auth1.printDetails()
print("===================")
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print("===================")
auth2.printDetails()
print("===================")
auth3 = Author('Paolo Coelho', 'The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# ---------
# Lists of books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# ---------
# Lists of books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# ---------
# Lists of books:
# The Alchemist
# The Fifth Mountain

# %%
#task-12
class TaxiLagbe:
  def __init__(self,no,l):
    self.number=no
    self.location=l

    self.nameList=[]
    self.costList=[]
    self.totalpass=0
    self.totalcost=0
  def addPassenger(self,*p):
    
    for elem in p:
      list2=elem.split("_")
      if len(self.nameList)<4:
        self.nameList.append(list2[0])
        self.costList.append(list2[1])
        self.totalcost+=int(list2[1])
        self.totalpass+=1
        print(f'Dear {list2[0]}!Welcome to TaxiLagbe.')
      else:
        print("Taxi Full! No more passengers can be added.")
      

        
    
  def printDetails(self):
    print(f'Trip info for Taxi number: {self.number} \nThis taxi can cover only {self.location} area. \nTotal passengers: {self.totalpass} \nPassenger lists: \n{",".join(self.nameList)} \nTotal collected fare: {self.totalcost}')

      
taxi1 = TaxiLagbe('1010-01', 'Dhaka')
print('-------------------------------')
taxi1.addPassenger('Walker_100', 'Wood_200')
taxi1.addPassenger('Matt_100')
taxi1.addPassenger('Wilson_105')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi1.addPassenger('Karen_200')
print('-------------------------------')
taxi1.printDetails()
print('-------------------------------')
taxi2 = TaxiLagbe('1010-02', 'Khulna')
taxi2.addPassenger('Ronald_115')
taxi2.addPassenger('Parker_215')
print('-------------------------------')
taxi2.printDetails()
# Out:
# -------------------------------
# Dear Walker!Welcome to TaxiLagbe.
# Dear Wood!Welcome to TaxiLagbe.
# Dear Matt!Welcome to TaxiLagbe.
# Dear Wilson!Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker,Wood,Matt,Wilson
# Total collected fare: 505
# -------------------------------
# Taxi Full! No more passengers can be added.
# -------------------------------
# Trip info for Taxi number: 1010-01
# This taxi can cover only Dhaka area.
# Total passengers: 4
# Passenger lists:
# Walker,Wood,Matt,Wilson
# Total collected fare: 505
# -------------------------------
# Dear Ronald!Welcome to TaxiLagbe.
# Dear Parker!Welcome to TaxiLagbe.
# -------------------------------
# Trip info for Taxi number: 1010-02
# This taxi can cover only Khulna area.
# Total passengers: 2
# Passenger lists:
# Ronald,Parker
# Total collected fare: 330

# %%
#task-13
class Account:
  def __init__(self,n="",b=0.0):
    self.name=n
    if self.name=="":
      self.name="Default Account"
    self.balance=b
  def details(self):
    return (f'{self.name}\n{self.balance}')
  def withdraw(self,p):
    self.money=p
    if self.balance-self.money>3070:
      print("Withdraw successful! New balance is:",(self.balance-self.money))
    else:
      print("Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.")
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930)
print("------------------------")
a2.withdraw(600)
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful! The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#task-14
class StudentDatabase:
  def __init__(self,n,id):
    self.name=n
    self.id=id
    
    self.grades={}
    self.dict1={}
  def calculateGPA(self,l,s):
    self.list1=l
    self.session=s

    self.dict1[self.session]=self.list1
    print(self.dict1,"self.dict1")
    sum=0
    l=[]
    for s,list1 in self.dict1.items():
      for elem in list1:
        a=elem.split(": ")
        l.append(a[0])
        sum+=float(a[1])
      cg=sum/len(l)

      d={}
      d[tuple(l)]=cg
      sum=0
      l=[]
    self.grades[self.session]=d
      
  
  def printDetails(self):
    print(f'Name: {self.name} \nID: {self.id}')
    for k,v in self.grades.items():
      print("Courses taken in",k)
      for i,j in v.items():
        for x in i:
          print(x)
        print("GPA:",j)
  


s1 = StudentDatabase('Pietro', '10101222')
s1.calculateGPA(['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2020')
s1.calculateGPA(['CSE250: 3.7', 'CSE330: 4.0'], 'Summer2021')
print(f'Grades for {s1.name}\n{s1.grades}')
print('------------------------------------------------------')
s1.printDetails()
s2 = StudentDatabase('Wanda', '10103332')
s2.calculateGPA(['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0'], 'Summer2022')
print('------------------------------------------------------')
print(f'Grades for {s2.name}\n{s2.grades}')
print('------------------------------------------------------')
s2.printDetails()
# Out:
# {'Summer2020': ['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0']} self.dict1
# {'Summer2020': ['CSE230: 4.0', 'CSE220: 4.0', 'MAT110: 4.0'], 'Summer2021': ['CSE250: 3.7', 'CSE330: 4.0']} self.dict1
# Grades for Pietro
# {'Summer2020': {('CSE230', 'CSE220', 'MAT110'): 4.0}, 'Summer2021': {('CSE250', 'CSE330'): 3.85}}
# ------------------------------------------------------
# Name: Pietro
# ID: 10101222
# Courses taken in Summer2020
# CSE230
# CSE220
# MAT110
# GPA: 4.0
# Courses taken in Summer2021
# CSE250
# CSE330
# GPA: 3.85
# {'Summer2022': ['CSE111: 3.7', 'CSE260: 3.7', 'ENG101: 4.0']} self.dict1
# ------------------------------------------------------
# Grades for Wanda
# {'Summer2022': {('CSE111', 'CSE260', 'ENG101'): 3.8000000000000003}}
# ------------------------------------------------------
# Name: Wanda
# ID: 10103332
# Courses taken in Summer2022
# CSE111
# CSE260
# ENG101
# GPA: 3.8000000000000003

# %%
#task-20
class Student:
  def __init__(self,n=None,d=None):
    self.name=n
    self.dept=d
    self.list1=[]
    if self.name==None and self.dept==None:
      print("Student name and department need to be set")
    elif self.dept==None:
      print(f'Department for {self.name} needs to be set.')
    else:
      print(f'{self.name} is from {self.dept} department')

  def update_name(self,n1):
    self.name=n1
  def update_department(self,d1):
    self.dept=d1
  def enroll(self,*course):
    courseList=list(course)
    self.list1+=courseList
  def printDetail(self):
    print(f'Name: {self.name} \nDepartment: {self.dept} \n{self.name} enrolled in {len(self.list1)} course(s):\n{",".join(self.list1)}')
s1 = Student()
print("=========================")
s2 = Student("Carol")
print("=========================")
s3 = Student("Jon", "EEE")
print("=========================")
s1.update_name("Bob")
s1.update_department("CSE")
s2.update_department("BBA")
s1.enroll("CSE110", "MAT110", "ENG091")
s2.enroll("BUS101")
s3.enroll("MAT110", "PHY111")
print("###########################")
s1.printDetail()
print("=========================")
s2.printDetail()
print("=========================")
s3.printDetail()
# Out:
# Student name and department need to be set
# ...
# Department for Carol needs to be set.
# ...
# Jon is from EEE department
# ...
# ###########################
# Name: Bob
# Department: CSE
# Bob enrolled in 3 course(s):
# CSE110,MAT110,ENG091
# ...
# Name: Carol
# Department: BBA
# Carol enrolled in 1 course(s):
# BUS101
# ...
# Name: Jon
# Department: EEE
# Jon enrolled in 2 course(s):
# MAT110,PHY111

# %%
#task-21
class Student:
  def __init__(self,n,id,d):
    self.name=n
    self.id=id
    self.dept=d
    self.list1=[]
    self.credit=0
  def advise(self,*courses):
    #self.courselist=list(course)
    self.list1+=list(courses)
    self.credit=len(self.list1)*3
    print(f'{self.name} you have taken {self.credit} credits.')
    print("List of courses:",",".join(self.list1))
    if self.credit<9:
      print("Status: You have to take at least",3-len(self.list1) ,"more course.")
    elif self.credit>12:
      print("Status: You have to drop a least",len(self.list1)-4 ,"more course.")
    else:
      print("Status:OK")
  def details(self):
    return (f'Name: {self.name} \nID: {self.id} \nDepartment: {self.dept}')

s1 = Student("Alice","20103012","CSE")
s2 = Student("Bob", "18301254","EEE")
s3 = Student("Carol", "17101238","CSE")
print("##########################")
print(s1.details())
print("##########################")
print(s2.details())
print("##########################")
s1.advise("CSE110", "MAT110", "PHY111")
print("##########################")
s2.advise("BUS101", "MAT120")
print("##########################")
s3.advise("MAT110", "PHY111", "ENG102","CSE111", "CSE230")
# Out:
# ##########################
# Name: Alice
# ID: 20103012
# Department: CSE
# ##########################
# Name: Bob
# ID: 18301254
# Department: EEE
# ##########################
# Alice you have taken 9 credits.
# List of courses: CSE110,MAT110,PHY111
# Status:OK
# ##########################
# Bob you have taken 6 credits.
# List of courses: BUS101,MAT120
# Status: You have to take at least 1 more course.
# ##########################
# Carol you have taken 15 credits.
# List of courses: MAT110,PHY111,ENG102,CSE111,CSE230
# Status: You have to drop a least 1 more course.

# %%
#task-22
class Hotel:
  def __init__(self,h):
    self.hname=h
    self.staffno=0
    self.guestno=0

    self.dict1={}
    self.dict2={}
  def addStuff(self,n,a,p="000"):
    self.name=n
    self.age=a
    self.phone=p
    self.staffno+=1
    self.dict1[self.staffno]=[self.name,self.age,self.phone]
    print(self.dict1)
    print(f'Staff with ID {self.staffno} is added.')

  def getStuffById(self,p):
    self.no=p
    
    return (f'Staff ID: {self.no} \nName: {self.name} \nAge: {self.age} \nPhone no.:{self.phone}')

  def addGuest(self,n1,a1,p1):
    
    self.name1=n1
    self.age1=a1
    self.phone1=p1
    self.guestno+=1
    print(f'Guest with ID {self.guestno} is created.')
    self.dict2[self.guestno]=[self.name1,self.age1,self.phone1]
    print(self.dict2)
  def getGuestById(self,q):
    self.no1=q
    
    return (f'Staff ID: {self.no1} \nName: {self.name1} \nAge: {self.age1} \nPhone no.:{self.phone1}')
  def allStaffs(self):
    for k,v in self.dict1.items():
      n=v[0]
      a=v[1]
      p=v[2]
      print(f'All Staffs: \nNumber of Staff: {self.staffno} \nStaff ID: {k} Name: {n} Age: {a} Phone no: {p}')
  def allGuest(self):
    for k,v in self.dict2.items():
      n=v[0]
      a=v[1]
      p=v[2]
      print(f'All Guests: \nNumber of Guests: {self.guestno} \nGuest ID: {k} Name: {n} Age: {a} Phone no: {p}')
h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest("Carol",35,"123")
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, "431")
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# {1: ['Adam', 26, '000']}
# Staff with ID 1 is added.
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.:000
# ...
# Guest with ID 1 is created.
# {1: ['Carol', 35, '123']}
# ...
# Staff ID: 1
# Name: Carol
# Age: 35
# Phone no.:123
# ...
# Guest with ID 2 is created.
# {1: ['Carol', 35, '123'], 2: ['Diana', 32, '431']}
# ...
# Staff ID: 2
# Name: Diana
# Age: 32
# Phone no.:431
# ...
# All Staffs:
# Number of Staff: 1
# Staff ID: 1 Name: Adam Age: 26 Phone no: 000
# ...
# All Guests:
# Number of Guests: 2
# Guest ID: 1 Name: Carol Age: 35 Phone no: 123
# All Guests:
# Number of Guests: 2
# Guest ID: 2 Name: Diana Age: 32 Phone no: 431

# %%
#task-23
class Author:
  def __init__(self,n=None):
    self.name=n
    self.d1={}
    self.bcount=0
  def addBook(self,b,g):
    self.book=b
    self.genre=g
    if self.name==None:
      print("A book can not be added without author name.")
    else:
      if self.genre not in self.d1:
        self.d1[self.genre]=[self.book]
      else:
        self.d1[self.genre].append(self.book)
      self.bcount+=1
    #print(self.d1)
    
    
  def setName(self,n1):
    self.name=n1
  def printDetail(self):
    print(f'Number of Book(s):{self.bcount} \nAuthor Name: {self.name}')
    for k,v in self.d1.items():
      print(k,":",",".join(v))


a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# A book can not be added without author name.
# ...
# Number of Book(s):1
# Author Name: Anna Kavan
# Science Fiction : Ice
# ...
# Number of Book(s):2
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon
# Horror : Megher Upor Bari
# ...
# Number of Book(s):3
# Author Name: Humayun Ahmed
# Science Fiction : Onnobhubon,Ireena
# Horror : Megher Upor Bari
# ...

# %%
#task-25
class Vaccine:
  def __init__(self,v,c,p):
    self.vaccineName=v
    self.country=c
    self.period=p

class Person:
  def __init__(self,n,a,o="General citizen"):
    self.name=n
    self.age=a
    self.occupation=o

  def pushVaccine(self,vac):


astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")

# %%
#task-19
class msgClass:
  def __init__(self):
    self.content = 0
class Q5:
  def __init__(self):
    
    self.sum = 1
    self.x = 2
    self.y = 3
  def methodA(self):
    x, y = 1, 1
    msg = []
    myMsg = msgClass()
    p=Q5()
    print(Q5(),"Q")
    print(p,"p")
    myMsg.content = self.x
    msg.append(myMsg)
    msg[0].content = self.y + myMsg.content
    self.y = self.y + self.methodB(msg[0])
    y = self.methodB(msg[0]) + self.y
    x = y + self.methodB(msg[0], msg)
    self.sum = x + y + msg[0].content
    print(x," ", y," ", self.sum)
  def methodB(self, mg1, mg2 = None):
    if mg2 == None:
      x, y = 5, 6
      y = self.sum + mg1.content
      self.y = y + mg1.content
      x = self.x + 7 +mg1.content
      self.sum = self.sum + x + y
      self.x = mg1.content + x +8
      print(x, " ", y," ", self.sum)
      return y

    else:
       x = 1
       self.y += mg2[0].content
       mg2[0].content = self.y + mg1.content
       x = x + 4 + mg1.content
       self.sum += x + self.y
       mg1.content = self.sum - mg2[0].content
       print(self.x, " ",self.y," ", self.sum)
       return self.sum
q = Q5()
q.methodA()
# Out:
# <__main__.Q5 object at 0x7f197c8c8c90> Q
# <__main__.Q5 object at 0x7f197c8c8f10> p
# 14   6   21
# 39   26   86
# 52   36   168
# 225   57   409

# %%
#task-18

class Test4:
  def __init__(self):
    self.sum, self.y = 0, 0
  def methodA(self):
    x, y = 0, 0
    msg = [0]
    msg[0] = 5
    y = y + self.methodB(msg[0])
    x = y + self.methodB(msg, msg[0])
    self.sum = x + y + msg[0]
    print(x, y, self.sum)
  def methodB(self, *args):
    if len(args) == 1:
      mg1 = args[0]
      x, y = 0, 0
      y = y + mg1
      x = x + 33 + mg1
      self.sum = self.sum + x + y
      self.y = mg1 + x + 2
      print(x, y, self.sum)
      return y
    else:
       mg2, mg1 = args
       x = 0
       self.y = self.y + mg2[0]
       x = x + 33 + mg1
       self.sum = self.sum + x + self.y
       mg2[0] = self.y + mg1
       mg1 = mg1 + x + 2
       print(x, self.y, self.sum)
       return self.sum
t3 = Test4()
t3.methodA()
t3.methodA()
t3.methodA()
t3.methodA()
# Out:
# 38 5 43
# 38 50 131
# 136 5 196
# 38 5 239
# 38 50 327
# 332 5 392
# 38 5 435
# 38 50 523
# 528 5 588
# 38 5 631
# 38 50 719
# 724 5 784

# %%
class Test5:
  def __init__(self):
    self.sum = 0
    self.y = 0
  def methodA(self): 
    x=y=k=0
    msg = [5] 
    while (k < 2):
      y += msg[0] 
      x = y + self.methodB(msg, k)
      self.sum = x + y + msg[0]
      print(x ," " , y, " " , self.sum)
      k+=1
  def methodB(self, mg2, mg1):
    x = 0
    self.y += mg2[0]
    x = x + 3 + mg1
    self.sum += x + self.y
    mg2[0] = self.y + mg1
    mg1 += x + 2
    print(x , " " ,self.y, " " , self.sum)
    return mg1
t1 = Test5()
t1.methodA()
t1.methodA()
t1.methodA()
# Out:
# 3   5   8
# 10   5   20
# 4   10   34
# 17   10   38
# 3   15   56
# 10   5   30
# 4   30   64
# 27   20   78
# 3   35   116
# 10   5   50
# 4   70   124
# 47   40   158

# %%
#task-16

class Quiz3A:
  def __init__(self, k = None):
    self.temp, self.sum, self.y = 4, 0, 0
    if k != None:
      self.temp += 1
      self.temp = self.temp
      self.sum = self.temp + k
      self.y = self.sum - 1
    else:
      self.y = self.temp - 1
      self.sum = self.temp + 1
      self.temp += 2 
  def methodB(self, m, n):
    x = 0
    self.temp += 1
    self.y = self.y + m + (self.temp)
    x = x + 2 + n
    self.sum = self.sum + x + self.y
    print(x, self.y, self.sum)
    return self.sum
a1 = Quiz3A()
a1.methodB(1,2)
a2 = Quiz3A(3)
a2.methodB(2,4)
a1.methodB(2,1)
a2.methodB(1,3)
# Out:
# 4 11 20
# 6 15 29
# 3 21 44
# 5 23 57
# 57

# %%
#task-15

class FinalT6A:
  def __init__(self, x, p):
    self.temp, self.sum, self.y = 4, 0, 1
    self.temp += 1
    self.y = self.temp - p
    self.sum = self.temp + x
    print(x, self.y, self.sum)
  def methodA(self):
    
    x = 0
    y = 0
    y = y + self.y
    x = self.y + 2 + self.temp
    self.sum = x + y + self.methodB(self.temp, y)
    print(x, y, self.sum)
  def methodB(self, temp, n):
    x = 0
    temp += 1
    self.y = self.y + temp
    x = x + 3 + n
    self.sum = self.sum + x + self.y
    print(x, self.y, self.sum)
    return self.sum
q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 4 7
# 7 10 24
# 11 4 39
# 13 16 68
# 17 10 95
